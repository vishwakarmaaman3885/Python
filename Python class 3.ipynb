# %% [markdown]
# ### Class-3(Python)

# %% [markdown]
# #### Logical Operators
# ##### And, Or, Not

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
True and True
# Out:
# True

# %%
# Lets define two variables having boolean values True and False-
START = True
STOP = False

# Print the values as it is
print(f"Defined value of START = {START}")
print(f"Defined value of STOP = {STOP} \n")

# if can also be written as - 
print(f"Defined value of START = {START}")
print(f"Value of STOP by negating START= {not START} \n")

# alternatively -
print(f"Value of START by negating STOP = {not STOP}")
print(f"Defined value of STOP = {STOP} \n")
# Out:
# Defined value of START = True
# Defined value of STOP = False
#
# Defined value of START = True
# Value of STOP by negating START= False
#
# Value of START by negating STOP = True
# Defined value of STOP = False

# %%
not True
# Out:
# False

# %%
not int(bool(0))
# Out:
# True

# %%
not int(bool(1))
# Out:
# False

# %%
not 1
# Out:
# False

# %%
not 0
# Out:
# True

# %%
not 100
# Out:
# False

# %%
not -1
# Out:
# False

# %%
START = 1
STOP = 0

# Print the values as it is
print(f"Defined value of START = {START}")
print(f"Defined value of STOP = {STOP} \n")

# if can also be written as - 
print(f"Defined value of START = {START}")
print(f"Value of STOP by negating START= {int(not START)} \n")

# alternatively -
print(f"Value of START by negating STOP = {int(not STOP)}")
print(f"Defined value of STOP = {STOP} \n")
# Out:
# Defined value of START = 1
# Defined value of STOP = 0
#
# Defined value of START = 1
# Value of STOP by negating START= 0
#
# Value of START by negating STOP = 1
# Defined value of STOP = 0

# %%
zero = 0
one = 1

print(f"boolean value of no. {zero} is {bool(zero)}")
print(f"boolean value of no. {one} is {bool(one)}")
print(f"negation of {zero} is {not zero} and negation of {one} is {not one}")
print("\n#------------------------#\n")
# Out:
# boolean value of no. 0 is False
# boolean value of no. 1 is True
# negation of 0 is True and negation of 1 is False
#
# #------------------------#

# %%
Some_negative_float = -5.99
Some_positive_float = 5.6

print(f"boolean value of no. {Some_negative_float} is {bool(Some_negative_float)}")
print(f"boolean value of no. {Some_positive_float} is {bool(Some_positive_float)}")
print(f"negation of {Some_negative_float} is {not Some_negative_float} \
and negation of {Some_positive_float} is {not Some_positive_float}")
# Out:
# boolean value of no. -5.99 is True
# boolean value of no. 5.6 is True
# negation of -5.99 is False and negation of 5.6 is False

# %% [markdown]
# #### Logical And

# %%
VEGETABLES = True
SALT = False
DISH = VEGETABLES and SALT

print(f"Dish contains VEGETABLES: {VEGETABLES}")
print(f"Dish contains SALT: {SALT}")
print(f"Hence dish prepared was good: {DISH}\n")
# Out:
# Dish contains VEGETABLES: True
# Dish contains SALT: False
# Hence dish prepared was good: False

# %%
True * True
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
not(False) * True
# Out:
# True

# %%
not False*False # BODMAS rule apply
# Out:
# True

# %%
not(False)*True
# Out:
# True

# %%
(not(False))*True
# Out:
# 1

# %%
print(not(False)*False)
# Out:
# True

# %%
print((not(False))*False)
# Out:
# 0

# %%
not(0)
# Out:
# True

# %%
not(1)
# Out:
# False

# %%
not False*True
# Out:
# True

# %% [markdown]
# ### 4.1.2 Equality Operators
#
# Following operations are present in python for equlity check operation-
#
# |Operators|Meaning|
# |-|-|
# |**is**|***a is b*** returns true if variable/identifiers a and b *points* to the *same object*|
# |**is not**|***a is not b*** returns true if variable/identifiers a and b *points* to the *different object*|
# |**==**|***a == b*** returns true if variable/identifiers a and b has same value|
# |**!=**|***a != b*** returns true if variable/identifiers a and b has different value|

# %%
lst_a = [1,2,3,4]
lst_b = [1,2,3,4]

# %%
print(id(lst_a))  # memory address we got
print(id(lst_b))
# Out:
# 2487185222528
# 2487184319360

# %%
lst_a is lst_b
# Out:
# False

# %%
lst_a = [1,2,3,4]
lst_b = lst_a

# %%
print(id(lst_a))
print(id(lst_b))
# Out:
# 2487185220800
# 2487185220800

# %%
str1 = "Aman"
str2 = "Aman"
print(id(str1))
print(id(str2))
# Out:
# 2487155141600
# 2487155141600

# %%
# Immutable
str1 = "Aman"
str2 = "Aman1"

# %%
print(id(str1))
print(id(str2))
# Out:
# 2487155141600
# 2487184599312

# %%
lst_a
# Out:
# [1, 2, 3, 4]

# %%
lst_a[0]=10

# %%
lst_a
# Out:
# [10, 2, 3, 4]

# %%
str1
# Out:
# 'Aman'

# %%
str1[0]
# Out:
# 'A'

# %%
str1[0]="M" ## str-Immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 str1[0]="M"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# #### Comparison operation

# %% [markdown]
# |Operation|Meaning|
# |:-:|:-:|
# | **<** |less than|
# | **<=** |less than or equal to|
# | **>** |greater than|
# | **>=** |greater than or equal to|

# %%
maxium_speed_of_bike = 150
max_speed_of_car = 200

print(f"bike is faster than car: {maxium_speed_of_bike >= max_speed_of_car}")
# Out:
# bike is faster than car: False

# %%
maxium_speed_of_bike = 200
max_speed_of_car = 200

print(f"bike is faster than car: {maxium_speed_of_bike >= max_speed_of_car}")
# Out:
# bike is faster than car: True

# %% [markdown]
# ## Arithmethic Operations
# |Operation|Meaning|
# |:-:|:-:|
# | **+** |addition|
# | **-** |subtraction|
# | **\*** |multiplication|
# | **/** |true division|
# | **//** |integer division|
# | **%** |the modulo operator|

# %%
a = 10
b = 75

# %%
a*b
# Out:
# 750

# %%
a+b
# Out:
# 85

# %%
a-b
# Out:
# -65

# %%
a/b
# Out:
# 0.13333333333333333

# %%
a//b # divide two numbers and return the whole-number result, rounding down.(floor)
# Out:
# 0

# %%
a%b # (remainder)
# Out:
# 10

# %% [markdown]
# ### Bitwise Operators
# |Operation|Meaning|
# |:-:|:-:|
# | **∼** |bitwise complement (prefix unary operator)|
# | **&** |bitwise and|
# | **\|** |bitwise or|
# | **^** |bitwise exclusive-or|
# | **<<** |shift bits left, filling in with zeros|
# | **>>** |shift bits right, filling in with sign bit|

# %%
var = 10 # ob - prefix to represent binary
bin(var)
# Out:
# '0b1010'

# %%
5 & 3 # both must be 1 # 5-101(binary number)
                        # 3-011 then 001 (1 is the answer)
# Out:
# 1

# %%
5 | 3 # If either one is 1
# Out:
# 7

# %%
5^3 # if they are diffferent than put 1 (xor)
# Out:
# 6

# %%
~5 # not - it changes 1 to 0 and 0 to 1 #not=opposite
# Out:
# -6

# %%
5<<1 #left shift-it moves the bits left (left shift multiply by 2)
# Out:
# 10

# %%
5>>1 #right shift-it moves the bits right(divide by 2)
# Out:
# 2

# %%
True|False
# Out:
# True

# %%
False&False
# Out:
# False

# %%
var
# Out:
# 10

# %%
var>>1
# Out:
# 5

# %%
var<<1
# Out:
# 20

# %% [markdown]
# ### Strings

# %%
"Welcome to the data science masters"
# Out:
# 'Welcome to the data science masters'

# %%
str1 = "Welcome to the data science masters"

# %%
type(str1)
# Out:
# str

# %%
## immutable
str1[0] = 12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 2
#       1 ## immutable
# ----> 2 str1[0] = 12
#
# TypeError: 'str' object does not support item assignment

# %%
str1 = "Aman Kumar"

# %%
str1
# Out:
# 'Aman Kumar'

# %%
string = "Pw Skills Data Science"

# %%
string[5]
# Out:
# 'ills Data Science'

# %%
# Slice Operation 
string[5:11]
# Out:
# 'ills D'

# %%
string[-1]
# Out:
# 'e'

# %%
string[-3:]
# Out:
# 'nce'

# %%
string[-7:-3]
# Out:
# 'Scie'

# %%
string[-7:5]
# Out:
# ''

# %%
string[7:5]
# Out:
# ''

# %%
string[:-1]
# Out:
# 'Pw Skills Data Scienc'

# %%
string[:]
# Out:
# 'Pw Skills Data Science'

# %%
name = "Karthik" 
name[-5:4]
# Out:
# 'rt'

# %%
string
# Out:
# 'Pw Skills Data Science'

# %%
string[::-1]
# Out:
# 'ecneicS ataD sllikS wP'

# %%
name = "Aman"
name[::-2]
# Out:
# 'nm'

# %%
name[2::-1]
# Out:
# 'amA'

# %%
course_name = "Data Science Masters"

# %%
course_name[5:12]
# Out:
# 'Science'

# %%
course_name[11:4:-1]
# Out:
# 'ecneicS'

# %%
# Cocatenation
course_name + "Course"
# Out:
# 'Data Science MastersCourse'

# %%
course_name[4:12:1]
# Out:
# ' Science'

# %%
print("Hello " +"Worlds")
# Out:
# Hello Worlds

# %%
course_name*5
# Out:
# 'Data Science MastersData Science MastersData Science MastersData Science MastersData Science Masters'

# %%
len(course_name)  # len-length
# Out:
# 20

# %%
# find function-indexing number
course_name.find("n")
# Out:
# 9

# %%
course_name.find("a",2,10)
# Out:
# 3

# %%
course_name.find("z")
# Out:
# -1

# %%
# count()
course_name.count('a')
# Out:
# 3

# %%
course_name.count(' ')  # when spacing is present
# Out:
# 2

# %%
course_name.count('')
# Out:
# 21

# %%
# string split function-split() function is used to break a string into smaller parts.
course_name.split(' ')
# Out:
# ['Data', 'Science', 'Masters']

# %%
course_name
# Out:
# 'Data Science Masters'

# %%
course_name.split('S')
# Out:
# ['Data ', 'cience Masters']

# %%
course_name.split('s')
# Out:
# ['Data Science Ma', 'ter', '']

# %%
course_name.partition('S')  # partition() is used to split a string into exactly 3 parts based on a specific separator.
# Out:
# ('Data ', 'S', 'cience Masters')

# %%
## String upper and lowercase
course_name.upper() #convert all letters in a string to uppercase (capital letters).
# Out:
# 'DATA SCIENCE MASTERS'

# %%
course_name.lower() # convert all letters in a string to lowercase(small letters).
# Out:
# 'data science masters'

# %%
course_name.swapcase() #Convert uppercase characters to lowercase and lowercase characters to uppercase.
# Out:
# 'dATA sCIENCE mASTERS'

# %%
course_name.title() # Return a version of the string where each word is titlecased.
# Out:
# 'Data Science Masters'

# %%
name = "aman kumar"

# %%
name.title()
# Out:
# 'Aman Kumar'
