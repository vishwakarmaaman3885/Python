# %% [markdown]
# #### Sets- Python(Class-5)

# %%
# A set is a collection of unique elements.
#Key features
# Uses curly braces {}
# Does not allow duplicates
# Unordered (no indexing)
# Mutable (you can add/remove items)

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s1 = {1,2,3,4,5}

# %%
type(s1)
# Out:
# set

# %%
s2 = {1,1,2,3,3,4,5,6,67,7,7,8,1}

# %%
s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 67}

# %%
l = list(s2) # convert into list

# %%
tuple(s2) # convert into tuple
# Out:
# (1, 2, 3, 4, 5, 6, 67, 7, 8)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 67, 7, 8]

# %%
set(l)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 67}

# %%
s4 = {1,2,3,4,[1,2,3,4]} # list cannot inside the sets because list is mutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s4 = {1,2,3,4,[1,2,3,4]}
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
s5 = {1,2,3,4, (1,2,3,4)}

# %%
s5 # tuple can inside the sets because tuple is immutable
# Out:
# {(1, 2, 3, 4), 1, 2, 3, 4}

# %%
s6 = {"Aman",'aman',1,2,3,4} # python is case sensitive

# %%
s6
# Out:
# {1, 2, 3, 4, 'Aman', 'aman'}

# %%
s7 = {'aman','aman',1,2,3,4}

# %%
s7
# Out:
# {1, 2, 3, 4, 'aman'}

# %%
s7[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 s7[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s7[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 s7[::-1]
#
# TypeError: 'set' object is not subscriptable

# %%
s7
# Out:
# {1, 2, 3, 4, 'aman'}

# %%
for i in s7:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# aman

# %%
s7.add(34)

# %%
s7
# Out:
# {1, 2, 3, 34, 4, 'aman'}

# %%
s7.add(2)

# %%
s7 # because sets want uniqueness
# Out:
# {1, 2, 3, 34, 4, 'aman'}

# %%
len(s7)
# Out:
# 6

# %%
s7.pop()
# Out:
# 1

# %%
s7.pop()
# Out:
# 2

# %%
s7
# Out:
# {3, 34, 4, 'aman'}

# %%
s7.pop() #pop() is used to remove and return an element from a list.
# Out:
# 3

# %%
s7
# Out:
# {34, 4, 'aman'}

# %%
s7.clear() # remove all the elements from a list.

# %%
s7
# Out:
# set()

# %%
s8 = {1,2,3,4}
s9 = {1,2,3,5}

# %%
s8.difference(s9)
# Out:
# {4}

# %%
s10 = {1,2,3,4}
s11 = {1,2,3,6}

# %%
s10.difference(s11)
# Out:
# {4}
