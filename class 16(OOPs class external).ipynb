# %% [markdown]
# #### Class methods

# %%
class details:
    def __init__(self,name,email):
        self.name = name
        self.email = email
    def student_details(self):
        print(self.name,self.email)

# %%
p1 = details('Aman','Aman@gmail.com')

# %%
p1.email
# Out:
# 'Aman@gmail.com'

# %%
p1.student_details()
# Out:
# Aman Aman@gmail.com

# %%
p1.name
# Out:
# 'Aman'

# %%
class student:
    def __init__(self,name,email):
        self.name = name
        self.email = email 
    @classmethod
    def details(cls,name,email):
        return cls(name,email)
    
    def student_details(self):
        print(self.name,self.email)

# %%
st1 = student.details("Raj","raj@gmail.com")

# %%
st1.email
# Out:
# 'raj@gmail.com'

# %%
st1.student_details()
# Out:
# Raj raj@gmail.com

# %%
class student1:
    mobile_number = 1234567890
    def __init__(self,name,email):
        self.name = name
        self.email = email 
    @classmethod
    def details(cls,name,email):
        return cls(name,email)
    
    def student_details(self):
        print(self.name,self.email,student1.mobile_number)

# %%
student1.mobile_number
# Out:
# 1234567890

# %%
st2 = student1.details("Ak","ak@gmail.com")

# %%
st2.student_details()
# Out:
# Ak ak@gmail.com 1234567890

# %%
st2_obj = student1("Rohan",'rohan@gmail.com')

# %%
st2_obj.student_details()
# Out:
# Rohan rohan@gmail.com 1234567890

# %%
class student1:
    mobile_number = 1234567890
    def __init__(self,name,email):
        self.name = name
        self.email = email 
    @classmethod
    def change_number(cls,mobile):
        student1.mobile_number = mobile
        
    @classmethod
    def details(cls,name,email):
        return cls(name,email)
    
    def student_details(self):
        print(self.name,self.email,student1.mobile_number)

# %%
student1.mobile_number
# Out:
# 1234567890

# %%
student1.change_number(2345678970)

# %%
student1.mobile_number
# Out:
# 2345678970

# %%
st2_obj = student1("Ayushi","ayushi@gmail.com")

# %%
st2_obj.name
# Out:
# 'Ayushi'

# %%
st2_obj.mobile_number
# Out:
# 2345678970

# %%
class student2:
    mobile_number = 1234567890
    def __init__(self,name,email):
        self.name = name
        self.email = email 
    @classmethod
    def change_number(cls,mobile):
        student1.mobile_number = mobile
        
    @classmethod
    def details(cls,name,email):
        return cls(name,email)
    
    def student_details(self):
        print(self.name,self.email,student1.mobile_number)

# %%
def course_details(cls,course_name):
    print("course_details",course_name)

# %%
student2.course_details = classmethod(course_details)

# %%
student2.course_details('data science masters')
# Out:
# course_details data science masters

# %%
st3 = student2('Vaishnavi','vaishnavi@gmail.com')

# %%
st3.course_details("web dev")
# Out:
# course_details web dev

# %%
class student4:
    mobile_number = 1234567890
    def __init__(self,name,email):
        self.name = name
        self.email = email 
    @classmethod
    def change_number(cls,mobile):
        student1.mobile_number = mobile
        
    @classmethod # decorator
    def details(cls,name,email):
        return cls(name,email)
    
    def student_details(self):
        print(self.name,self.email,student1.mobile_number)

# %%
del student4.change_number # delete external method

# %%
student4.change_number(23445677)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 student4.change_number(23445677)
#
# AttributeError: type object 'student4' has no attribute 'change_number'

# %%
delattr(student4,'student_details')   # delattr- delete the value

# %%
student4.student_details()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 student4.student_details()
#
# AttributeError: type object 'student4' has no attribute 'student_details'

# %%
student4.mobile_number
# Out:
# 1234567890

# %%
delattr(student4,'mobile_number')

# %%
student4.mobile_number
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 student4.mobile_number
#
# AttributeError: type object 'student4' has no attribute 'mobile_number'
