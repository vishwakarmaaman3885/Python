# %% [markdown]
# #### OPPS- stands for object oriented programming system

# %%
a = 1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type("pwskills")) # class- A class is a blueprint or template used to create objects.
# Out:
# <class 'str'>

# %%
class Student: # Student → class,s1 → object,name, age → attributes/data
    name = "Aman"
    age = 20

# %%
s1 = Student()

# %%
class test:
    pass

# %%
a = test()

# %%
print(type(a))
# Out:
# <class '__main__.test'>

# %%
class pwskills:
    def welcome_msg(self):
        print("welcome to pwskills")

# %%
rohan = pwskills()

# %%
rohan.welcome_msg()
# Out:
# welcome to pwskills

# %%
aman = pwskills()

# %%
aman.welcome_msg()
# Out:
# welcome to pwskills

# %%
a=1

# %%
b=2

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
class pwskills1: # __init__ is a constructor method that automatically runs when an object is created and initializes 
                  #the object's attributes.
    
    def __init__(self,phone_number,email_id,student_id):
        self.phone_number = phone_number
        self.email_id = email_id
        self.student_id = student_id
    
    def return_student_details(self):
        return self.phone_number, self.email_id, self.student_id

# %%
rohan = pwskills1(45678,"rohan@gmail.com", 101)

# %%
rohan.phone_number
# Out:
# 45678

# %%
rohan.email_id
# Out:
# 'rohan@gmail.com'

# %%
rohan.student_id
# Out:
# 101

# %%
rohan.return_student_details()
# Out:
# (45678, 'rohan@gmail.com', 101)

# %%
sohan = pwskills1(234567,"sohan@gmail.com", 123)

# %%
sohan.return_student_details()
# Out:
# (234567, 'sohan@gmail.com', 123)

# %%
sohan.email_id
# Out:
# 'sohan@gmail.com'

# %%
class pwskills2:
    def __init__(aman,mobile_number,email_id,student_id):
        aman.mobile_number=mobile_number
        aman.email_id = email_id
        aman.student_id = student_id
    def return_student_details(aman):
        return aman.mobile_number, aman.email_id, aman.student_id

# %%
raj = pwskills2(123456,"raj@gmail.com",101)

# %%
raj.email_id
# Out:
# 'raj@gmail.com'

# %%
raj.mobile_number
# Out:
# 123456

# %%
raj.return_student_details()
# Out:
# (123456, 'raj@gmail.com', 101)

# %%
class pwskills3:
    def __init__(aman,mobile_number,email_id,student_id):
        aman.mobile_number1=mobile_number # mobile_number1 in this value i can used
        aman.email_id = email_id
        aman.student_id = student_id
    def return_student_details(aman):
        return aman.mobile_number1, aman.email_id, aman.student_id

# %%
ayushi = pwskills3(7389356100,"ayushi@gmail.com",109)

# %%
ayushi.mobile_number
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 ayushi.mobile_number
#
# AttributeError: 'pwskills3' object has no attribute 'mobile_number'

# %%
ayushi.mobile_number1
# Out:
# 7389356100

# %%
ayushi.return_student_details()
# Out:
# (7389356100, 'ayushi@gmail.com', 109)
