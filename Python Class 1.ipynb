# %% [markdown]
# ### Python- First Class(Data Science)

# %%
a=1+1

# %%
a
# Out:
# 2

# %%
# Comments -a comment is text that is ignored by the interpreter and is used to explain code 
# or leave notes for developers.
# sinle line comment(#)
a=20
a
# Out:
# 20

# %%
# Multi-line comment- (Triple quotes)
"""
This is my first class of python   
"""
a=30
a
# Out:
# 30

# %%
# Markdown is used for writing title,heading and description

# %% [markdown]
# ### Numbers

# %%
1+3
# Out:
# 4

# %%
print(1+3)
# Out:
# 4

# %%
a=5

# %%
a
# Out:
# 5

# %%
print(a) # print-show the result
# Out:
# 5

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("My name is Aman and
      I am a computer science student")
# Out:
#   Cell In[14], line 1
#     print("My name is Aman
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("My name is Aman and \n I am a computer science student")
# Out:
# My name is Aman
#  I am a computer science student

# %% [markdown]
# ### Variable - Is a container that stores data in memory

# %%
name = "Aman"
Place = "Indore"

# %%
name
# Out:
# 'Aman'

# %%
# str - writting always (" ")
" "
type(" ")
# Out:
# str

# %%
decimal_num = 9.8
print(decimal_num)
print(type(decimal_num))
# Out:
# 9.8
# <class 'float'>

# %%
type(1+3j)
# Out:
# complex

# %%
## bad way- Don't start the variable name with numbers
1a
2answer

# %%
# variables are case sensitive
name = "Aman"
Name = "Vidhi"
print(name)
print(Name)
# Out:
# Aman
# Vidhi

# %%
# Reserved keywords
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
# Boolean-True,False
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
a = 1
if bool(a)==True:
    print("True")
# Out:
# True

# %%
type(bool(a)) == True
# Out:
# False

# %%
# Typecasting-changing data one type to another
str(23)
# Out:
# '23'

# %%
print(type(str(23)))
# Out:
# <class 'str'>

# %%
# Kernal - A kernel is the engine that runs your Python code.
